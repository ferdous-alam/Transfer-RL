# %%
import numpy as np
import torch
import torch.optim as optim
import torch.nn.functional as F
import torch.nn as nn
import matplotlib
import gym
import matplotlib.pyplot as plt
from tqdm import tqdm
from utils import core
from utils import models
from utils import helper
from pathlib import Path
import time 
from colabgymrender.recorder import Recorder

# %%
def get_action(ac, o, deterministic=False):
    return ac.act(torch.as_tensor(o, dtype=torch.float32), 
                    deterministic)


def run_trained_policy(env, max_ep_len=1000, 
                       num_runs=1, load_path=None, 
                       render=False, f_name=None):

    # initialize environment and make a copy
    test_env = Recorder(env, 'video/')
    # initialize policy network
    actor_critic = core.MLPActorCritic
    # Create actor-critic module and target networks
    ac_kwargs = dict(hidden_sizes=[200]*4)
    ac = actor_critic(test_env.observation_space, test_env.action_space, **ac_kwargs)
    ac.load_state_dict(torch.load(load_path))
    

    ep_reward_cache = []
    for n in range(num_runs):
        ret, ep_len = 0, 0
        reward_cache = []
        obs, done = test_env.reset(), False    
        while not done or (ep_len == max_ep_len):
            if render:
                test_env.render()
                time.sleep(0.05)
            act = get_action(ac, obs, True)
            obs2, reward, done, _ = test_env.step(act)
            ret += reward
            reward_cache.append(reward)
            obs = obs2
            if done:
                break
        ep_reward_cache.append(reward_cache)
        test_env.close()
    print(f'total average return: {ret}')

    # save data
    if f_name is not None:
        Path('data/{}'.format(f_name)).mkdir(parents=True, exist_ok=True)
        np.save(f'data/{f_name}/eval_policy_rewards.npy', ep_reward_cache)


load_path = 'data/half_cheetah_dyn_0_reward_-1.0_sac/policy.pth'
xml = f'/home/ghost-083/Research/1_Transfer_RL/D3M/envs/halfcheetah/assets/half_cheetah_0.xml'
env = gym.make('HalfCheetah-v3', xml_file=xml, 
                forward_reward_weight=-1.0, 
                ctrl_cost_weight=0.1, 
                reset_noise_scale=0.1
                )
run_trained_policy(env=env, num_runs=1, 
                load_path=load_path, max_ep_len=200,
                render=True, f_name='pendulum_eval_16.0')
# Out:
# Found 4 GPUs for rendering. Using device 0.
# Could not make EGL context current
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_48908/1929480014.py in <module>
#      51                 reset_noise_scale=0.1
#      52                 )
# ---> 53 run_trained_policy(env=env, num_runs=1,
#      54                 load_path=load_path, max_ep_len=200,
#      55                 render=True, f_name='pendulum_eval_16.0')
#
# /tmp/ipykernel_48908/1929480014.py in run_trained_policy(env, max_ep_len, num_runs, load_path, render, f_name)
#       9
#      10     # initialize environment and make a copy
# ---> 11     test_env = Recorder(env, 'video/')
#      12     # initialize policy network
#      13     actor_critic = core.MLPActorCritic
#
# ~/anaconda3/envs/RLkit/lib/python3.9/site-packages/colabgymrender/recorder.py in __init__(self, env, directory, auto_release, size, fps)
#      18         if size is None:
#      19             self.env.reset()
# ---> 20             self.size = self.env.render(mode = 'rgb_array').shape[:2][::-1]
#      21         else:
#      22             self.size = size
#
# ~/anaconda3/envs/RLkit/lib/python3.9/site-packages/gym/core.py in render(self, mode, **kwargs)
#     293
#     294     def render(self, mode="human", **kwargs):
# --> 295         return self.env.render(mode, **kwargs)
#     296
#     297     def close(self):
#
# ~/anaconda3/envs/RLkit/lib/python3.9/site-packages/gym/envs/mujoco/mujoco_env.py in render(self, mode, width, height, camera_id, camera_name)
#     155                 camera_id = self.model.camera_name2id(camera_name)
#     156
# --> 157             self._get_viewer(mode).render(width, height, camera_id=camera_id)
#     158
#     159         if mode == "rgb_array":
#
# ~/anaconda3/envs/RLkit/lib/python3.9/site-packages/gym/envs/mujoco/mujoco_env.py in _get_viewer(self, mode)
#     184                 self.viewer = mujoco_py.MjViewer(self.sim)
#     185             elif mode == "rgb_array" or mode == "depth_array":
# --> 186                 self.viewer = mujoco_py.MjRenderContextOffscreen(self.sim, -1)
#     187
#     188             self.viewer_setup()
#
# mjrendercontext.pyx in mujoco_py.cymj.MjRenderContext.__init__()
#
# mjrendercontext.pyx in mujoco_py.cymj.MjRenderContext._setup_opengl_context()
#
# opengl_context.pyx in mujoco_py.cymj.OffscreenOpenGLContext.__init__()
#
# RuntimeError: Failed to initialize OpenGL
